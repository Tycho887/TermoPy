# %%
import termoPy as tp

atm = tp.atm

isobar = tp.Isobaric(P1=1*atm, T1=300, V1=0.1,gas='Acetone')
print(isobar.fluid)
isobar.generate_data_from_dV(0.01)
isobar.plot_PV()
print(isobar.work_done_by)
isobar.generate_data_from_dV(1)
isobar.plot_PV()
print(isobar.work_done_by)
# Out:
# {'formula': 'C3H6O', 'M': 0.05808, 'Cp': 85.3776, 'Cv': 76.6656, 'gamma': 1.1136363636363635}
# -9117.000000000002
# 91170.0

# %%
carnot = tp.Carnot(P1=1*atm, T_cold=300, T_hot=400, n=10, compression_ratio=2)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# c:\Users\Jobb og Skole\OneDrive - Norwegian University of Life Sciences\Desktop\FYSLAB\termo_test.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Jobb%20og%20Skole/OneDrive%20-%20Norwegian%20University%20of%20Life%20Sciences/Desktop/FYSLAB/termo_test.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> carnot = tp.Carnot(P1=1*atm, T_cold=300, T_hot=400, n=10, compression_ratio=2)
#
# File c:\Users\Jobb og Skole\OneDrive - Norwegian University of Life Sciences\Desktop\FYSLAB\termoPy.py:659, in Carnot.__init__(self, compression_ratio, T_hot, T_cold, P1, V1, n, monatomic, diatomic, gas)
#     657 self._find_missing()
#     658 self._calculate_alpha_beta()
# --> 659 self.run_cycle()
#
# File c:\Users\Jobb og Skole\OneDrive - Norwegian University of Life Sciences\Desktop\FYSLAB\termoPy.py:614, in BaseCycle.run_cycle(self)
# ...

# %%
# list of dicts

f = [{'a': 1, 'b': 2}, {'a': 3, 'b': 4}, {'a': 5, 'b': 6}]
test_dict = {'a': 1, 'b': 2}

print(test_dict in f)
# Out:
# True
